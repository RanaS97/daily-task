# %%
import numpy as np
import pandas as pd
ds=pd.read_csv("/content/insurence.csv")
ds.head()
# Out:
#    age  height  weight  premium
# 0   25  162.56      70    18000
# 1   30  172.56      95    38000
# 2   35  167.64      78    38000
# 3   40  165.02     110    60000
# 4   45  157.48      85    70000

# %%
x=ds['age']
y=ds['premium']
x,y
# Out:
# (0    25
#  1    30
#  2    35
#  3    40
#  4    45
#  Name: age, dtype: int64,
#  0    18000
#  1    38000
#  2    38000
#  3    60000
#  4    70000
#  Name: premium, dtype: int64)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)

# %%
xtrain,xtest,ytrain
# Out:
# (0    25
#  4    45
#  2    35
#  Name: age, dtype: int64,
#  1    30
#  3    40
#  Name: age, dtype: int64,
#  0    18000
#  4    70000
#  2    38000
#  Name: premium, dtype: int64)
